# %%
import pandas as pd

# %%
base_path = './합본'
years = ['/22', '/23']
regions = ['/수도권', '/동부', '/서부', '/제주산간']
csv_types = ['/TL_csv/', '/VL_csv/']

file_names = ['tn_visit_area_info_방문지정보', 'tn_traveller_master_여행객 Master', 'tn_travel_여행', 'tn_tour_photo_관광사진',
            'tn_mvmn_consume_his_이동수단소비내역', 'tn_move_his_이동내역', 'tn_lodge_consume_his_숙박소비내역', 'tn_companion_info_동반자정보',
             'tn_adv_consume_his_사전소비내역', 'tn_activity_his_활동내역', 'tn_activity_consume_his_활동소비내역' ]

year_region_codes = {
    '/22': ['_A', '_B', '_C', '_D'],  # 22년도 수도권 A, 동부 B, 서부 C, 제주산간 D
    '/23': ['_E', '_F', '_G', '_H']   # 23년도 수도권 E, 동부 F, 서부 G, 제주산간 H
}

# %%
# import os

# # 파일 생성 혹은 경로 출력 코드
# for year in years:
#     for region, code in zip(regions, year_region_codes[year]):
#         for csv_type in csv_types:
#             for file_name in file_names:
#                 # 경로를 생성
#                 file_path = f"{base_path}{year}{region}{csv_type}{file_name}{code}.csv"
#                 # 파일 생성 또는 경로 출력
#                 print(file_path)

# %%
import os

m_df =[]
year = '/23'

for file_name in file_names:
    dfs = []
    for region, code in zip(regions, year_region_codes[year]):
        for csv_type in csv_types:
            file_path = f"{base_path}{year}{region}{csv_type}{file_name}{code}.csv"
            df = pd.read_csv(file_path)
            dfs.append(df)
    mdf = pd.concat(dfs)
    m_df.append(mdf)
m_df_dict = {file_name: df for file_name, df in zip(file_names, m_df)}

# %%
for fn in file_names:
    m_df_dict[fn].to_csv(f"{fn}.csv", index = False)

# %%
m_df_dict['tn_traveller_master_여행객 Master'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11520 entries, 0 to 319
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   TRAVELER_ID                11520 non-null  object
#  1   RESIDENCE_SGG_CD           11520 non-null  int64
#  2   GENDER                     11520 non-null  object
#  3   AGE_GRP                    11520 non-null  int64
#  4   EDU_NM                     11520 non-null  int64
#  5   EDU_FNSH_SE                11518 non-null  float64
#  6   MARR_STTS                  11520 non-null  int64
#  7   FAMILY_MEMB                11520 non-null  int64
#  8   JOB_NM                     11520 non-null  int64
#  9   JOB_ETC                    0 non-null      float64
#  10  INCOME                     11520 non-null  int64
#  11  HOUSE_INCOME               8856 non-null   float64
#  12  TRAVEL_TERM                11520 non-null  int64
# ...

# %%
ls = []
for nm in m_df_dict['tn_lodge_consume_his_숙박소비내역']['LODGING_NM']:
    ls.append('집' in nm)
m_df_dict['tn_lodge_consume_his_숙박소비내역'][ls]
# Out:
#       TRAVEL_ID LODGING_NM  LODGING_PAYMENT_SEQ  LODGING_TYPE_CD RSVT_YN  \
# 83    e_e000647    친구의 친지집                    0               10       N
# 108   e_e000791       친구 집                    0               10       Y
# 186   e_e001247        친지집                    0               10       N
# 338   e_e002965        친척집                    0               10       N
# 435   e_e003515       동생 집                    0               10       Y
# ...         ...        ...                  ...              ...     ...
# 3141  h_h006665          집                    0                3       N
# 217   h_h001722      나의제주집                    0                8       Y
# 218   h_h001722      나의제주집                    1                8       Y
# 350   h_h005220         빵집                    1                7       Y
# 359   h_h005456        친지집                    0               10       N
#
#       CHK_IN_DT_MIN  CHK_OUT_DT_MIN  PAYMENT_NUM  BRNO STORE_NM  \
# ...

# %%
ls = []
for nm in m_df_dict['tn_lodge_consume_his_숙박소비내역']['LODGING_NM']:
    ls.append('사우나' in nm)
m_df_dict['tn_lodge_consume_his_숙박소비내역'][ls]
# Out:
#       TRAVEL_ID    LODGING_NM  LODGING_PAYMENT_SEQ  LODGING_TYPE_CD RSVT_YN  \
# 215   e_e001548       스파렉스사우나                    1               11       N
# 144   f_f000476       온천호텔사우나                    1                2       Y
# 972   f_f005468  코오롱호텔 경주 사우나                    1                1       Y
# 1078  f_f006957     그린빌사우나찜질방                    1               11       N
# 96    f_f004910       수정사우나모텔                    0                2       Y
# 272   g_g002955    유성온천불가마사우나                    0               11       N
# 1026  g_g002955    유성온천불가마사우나                    1               11       N
# 9     f_f004503       오션스파사우나                    1               11       N
#
#       CHK_IN_DT_MIN  CHK_OUT_DT_MIN  PAYMENT_NUM  BRNO     STORE_NM  \
# 215             NaN             NaN            1   NaN   스파렉스 굿모닝시티
# 144             NaN             NaN            2   NaN      주식회사 온다
# 972             NaN             NaN            4   NaN     (주)현대홈쇼핑
# ...

# %%
ls = []
for nm in m_df_dict['tn_lodge_consume_his_숙박소비내역']['LODGING_NM']:
    ls.append('스파' in nm)
m_df_dict['tn_lodge_consume_his_숙박소비내역'][ls]
# Out:
#      TRAVEL_ID        LODGING_NM  LODGING_PAYMENT_SEQ  LODGING_TYPE_CD  \
# 215  e_e001548           스파렉스사우나                    1               11
# 253  e_e002214            스파아일랜드                    0               11
# 303  e_e002589         테라피신축스파펜션                    1                3
# 362  e_e003109       슈가풀빌라&스파글램핑                    1                3
# 389  e_e003280          또바기스파글램핑                    1                5
# ..         ...               ...                  ...              ...
# 193  h_h001264    JW메리어트제주리조트&스파                    0                1
# 221  h_h001792  제주도게스트하우스파티 한담누리                    1                7
# 253  h_h002381             로맨스파파                    0                3
# 290  h_h003127            제주담스파빌                    0                3
# 366  h_h005809         씨스테이호텔&스파                    1                3
#
#     RSVT_YN  CHK_IN_DT_MIN  CHK_OUT_DT_MIN  PAYMENT_NUM  BRNO  \
# ...

# %%
lodgings = m_df_dict['tn_lodge_consume_his_숙박소비내역']

# %%
lodgings['LODGING_TYPE_CD'].value_counts()
# Out:
# LODGING_TYPE_CD
# 1     2893
# 3     1337
# 4      767
# 2      691
# 7      590
# 5      411
# 11     296
# 8      177
# 9      139
# 6      116
# 10      65
# Name: count, dtype: int64

# %%
lodgings[lodgings['LODGING_TYPE_CD'] == 11]
# Out:
#      TRAVEL_ID        LODGING_NM  LODGING_PAYMENT_SEQ  LODGING_TYPE_CD  \
# 17   e_e000347              펠리스빌                    0               11
# 111  e_e000810               소담빌                    1               11
# 121  e_e000856          맹그로브 신설점                    0               11
# 148  e_e001001            양평불한증막                    0               11
# 178  e_e001200  에어비앤비 blessing20                    1               11
# ..         ...               ...                  ...              ...
# 179  h_h001066     에어비앤비, 테라스인제주                    1               11
# 205  h_h001412            미도스카이빌                    1               11
# 231  h_h001926          울릉크루즈선착장                    0               11
# 254  h_h002398        강화 황산도 해변로                    0               11
# 358  h_h005456         서귀포우체국수련원                    0               11
#
#     RSVT_YN  CHK_IN_DT_MIN  CHK_OUT_DT_MIN  PAYMENT_NUM  BRNO STORE_NM  \
# ...

# %%
lodgings['TRAVEL_ID'].value_counts()
# Out:
# TRAVEL_ID
# h_h000645    7
# f_f000430    7
# h_h000599    6
# h_h001182    6
# h_h002260    6
#             ..
# f_f013463    1
# f_f013437    1
# f_f013431    1
# f_f013425    1
# h_h006753    1
# Name: count, Length: 5588, dtype: int64

# %%
m_df[1]['TRAVEL_STATUS_ACCOMPANY'].value_counts()
# Out:
# TRAVEL_STATUS_ACCOMPANY
# 2인 여행(가족 외)           3990
# 나홀로 여행                2163
# 자녀 동반 여행              1902
# 3인 이상 여행(가족 외)        1424
# 2인 가족 여행              1293
# 부모 동반 여행               484
# 3대 동반 여행(친척 포함)        252
# 3인 이상 가족 여행(친척 포함)      12
# Name: count, dtype: int64

# %% [markdown]
# 가구 소득이 없는 경우 -> 1인 가구라서 개인 소득 = 가구 소득으로 할 수 있음
#
# 숙소 "사우나" 행 제거
#
# EDA 해보면서 연령에 따른 여행 성향 분석
#
# 페르소나 컬럼을

# %%
dfs = []
year = '/23'
for region, code in zip(regions, year_region_codes[year]):
    for csv_type in csv_types:
        file_name = 'tn_traveller_master_여행객 Master'
        # 경로를 생성
        file_path = f"{base_path}{year}{region}{csv_type}{file_name}{code}.csv"
        # 파일 생성 또는 경로 출력
        dfs.append(pd.read_csv(file_path))

# %%
# 여행자 ID를 담을 리스트
traveler_ids = []

# 각 데이터프레임에서 "TRAVELER_ID" 컬럼 추출
for df in dfs:
    if 'TRAVELER_ID' in df.columns:
        # ID의 첫 번째 문자를 제거하고 리스트에 추가
        traveler_ids.extend(df['TRAVELER_ID'].astype(str).apply(lambda x: x[1:] if len(x) > 1 else x).tolist())

from collections import Counter

# traveler_ids 리스트에서 각 값의 등장 횟수를 셈
id_counts = Counter(traveler_ids)

# 등장 횟수가 2번 이상인 값만 필터링
duplicate_ids = {key: value for key, value in id_counts.items() if value > 1}
