# %%
import pandas as pd
import requests
import time
import os

# 카카오 API 키
api_key = ""

# 입력 파일 경로와 출력 파일 경로
input_file_path = "tn_visit_area_info_방문지정보_depth_cleaned_score.csv"  # 로컬 파일 경로
output_file_path = "tn_visit_area_info_방문지정보2nd.csv"  # 저장할 파일 경로

# 데이터 로드
if os.path.exists(output_file_path):
    print(f"Resuming from saved file: {output_file_path}")
    activity_consume_df = pd.read_csv(output_file_path, encoding='utf-8-sig')
else:
    print(f"Starting fresh with input file: {input_file_path}")
    activity_consume_df = pd.read_csv(input_file_path, encoding='utf-8-sig')

# 4개 값이 모두 없는 행 제거
print(f"Initial data size: {activity_consume_df.shape}")
activity_consume_df = activity_consume_df.dropna(subset=['ROAD_NM_ADDR', 'LOTNO_ADDR', 'X_COORD', 'Y_COORD'], how='all')
print(f"Data size after removing rows with all 4 values missing: {activity_consume_df.shape}")

# 캐시 초기화
geocode_cache = {}

# 지오코딩 함수 정의
def get_geocode(address, api_key, timeout=5):
    if address in geocode_cache:
        print(f"Cache hit for address: {address}")
        return geocode_cache[address]

    url = f"https://dapi.kakao.com/v2/local/search/address.json?query={address}"
    headers = {"Authorization": f"KakaoAK {api_key}"}
    print(f"Attempting to geocode address: {address}")
    try:
        response = requests.get(url, headers=headers, timeout=timeout)
        if response.status_code == 200:
            result = response.json()
            if result.get('documents'):
                document = result['documents'][0]
                road_address = document.get('address_name')
                x_coord = document.get('x')
                y_coord = document.get('y')
                geocode_cache[address] = (road_address, x_coord, y_coord)
                print(f"Geocode success for address: {address}")
                return road_address, x_coord, y_coord
            else:
                print(f"No results found for address: {address}")
        else:
            print(f"API error for address: {address}, Status code: {response.status_code}, Response: {response.text}")
    except requests.exceptions.Timeout:
        print(f"Timeout error for address: {address}")
    except requests.exceptions.RequestException as e:
        print(f"Request error for address: {address}, Error: {e}")
    return None, None, None

# X_COORD, Y_COORD로 ROAD_NM_ADDR 채우기
def fill_road_nm_from_coords(row):
    x_coord = row['X_COORD']
    y_coord = row['Y_COORD']
    if pd.notna(x_coord) and pd.notna(y_coord):
        print(f"Attempting to fill ROAD_NM_ADDR using coordinates: ({x_coord}, {y_coord})")
        reverse_url = f"https://dapi.kakao.com/v2/local/geo/coord2address.json?x={x_coord}&y={y_coord}"
        headers = {"Authorization": f"KakaoAK {api_key}"}
        try:
            response = requests.get(reverse_url, headers=headers)
            if response.status_code == 200:
                result = response.json()
                if result.get('documents'):
                    address = result['documents'][0].get('address')
                    if address:
                        print(f"ROAD_NM_ADDR found: {address.get('address_name')}")
                        return address.get('address_name')
            else:
                print(f"API error for coordinates ({x_coord}, {y_coord}), Status code: {response.status_code}, Response: {response.text}")
        except requests.exceptions.Timeout:
            print(f"Timeout error for coordinates ({x_coord}, {y_coord})")
        except requests.exceptions.RequestException as e:
            print(f"Request error for coordinates ({x_coord}, {y_coord}), Error: {e}")
    return None

# LOTNO_ADDR로 ROAD_NM_ADDR 채우기
def fill_road_nm_from_lotno(lotno_addr):
    if pd.notna(lotno_addr):
        print(f"Attempting to fill ROAD_NM_ADDR using LOTNO_ADDR: {lotno_addr}")
        road_addr, _, _ = get_geocode(lotno_addr, api_key)
        if road_addr:
            print(f"ROAD_NM_ADDR found from LOTNO_ADDR: {road_addr}")
        return road_addr
    return None

# SIDO_NM, SGG_NM, DONG_NM, RI_NM 정보 추가
def get_region_info(address):
    if pd.notna(address):
        print(f"Attempting to retrieve region info for ROAD_NM_ADDR: {address}")
        road_addr, _, _ = get_geocode(address, api_key)
        if road_addr:
            url = f"https://dapi.kakao.com/v2/local/search/address.json?query={address}"
            headers = {"Authorization": f"KakaoAK {api_key}"}
            try:
                response = requests.get(url, headers=headers)
                if response.status_code == 200:
                    result = response.json()
                    if result.get('documents') and result['documents'][0].get('address'):
                        addr = result['documents'][0]['address']
                        print(f"Region info found: {addr}")
                        return (
                            addr.get('region_1depth_name'),  # SIDO_NM
                            addr.get('region_2depth_name'),  # SGG_NM
                            addr.get('region_3depth_name'),  # DONG_NM
                            addr.get('region_4depth_name')   # RI_NM
                        )
                else:
                    print(f"API error for region info ({address}), Status code: {response.status_code}, Response: {response.text}")
            except requests.exceptions.Timeout:
                print(f"Timeout error for region info ({address})")
            except requests.exceptions.RequestException as e:
                print(f"Request error for region info ({address}), Error: {e}")
    return None, None, None, None

# 데이터 처리
try:
    print("Processing ROAD_NM_ADDR, X_COORD, Y_COORD...")
    for index, row in activity_consume_df.iterrows():
        if pd.isna(row['ROAD_NM_ADDR']):
            road_nm = fill_road_nm_from_coords(row)
            if road_nm is None:
                road_nm = fill_road_nm_from_lotno(row['LOTNO_ADDR'])
            activity_consume_df.at[index, 'ROAD_NM_ADDR'] = road_nm
        
        if pd.notna(row['ROAD_NM_ADDR']):
            if pd.isna(row['X_COORD']) or pd.isna(row['Y_COORD']):
                _, x_coord, y_coord = get_geocode(row['ROAD_NM_ADDR'], api_key)
                activity_consume_df.at[index, 'X_COORD'] = x_coord
                activity_consume_df.at[index, 'Y_COORD'] = y_coord
            if pd.isna(row['LOTNO_ADDR']):
                road_addr, _, _ = get_geocode(row['ROAD_NM_ADDR'], api_key)
                activity_consume_df.at[index, 'LOTNO_ADDR'] = road_addr

    print("Processing SIDO_NM, SGG_NM, DONG_NM, RI_NM...")
    for index, row in activity_consume_df.iterrows():
        if all(pd.isna(row[col]) for col in ['SIDO_NM', 'SGG_NM', 'DONG_NM']):
            region_info = get_region_info(row['ROAD_NM_ADDR'])
            if all(val is None for val in region_info):
                print(f"Removing row {index} due to missing region info")
                activity_consume_df.drop(index, inplace=True)
            else:
                print(f"Region info updated for row {index}")
                activity_consume_df.loc[index, ['SIDO_NM', 'SGG_NM', 'DONG_NM', 'RI_NM']] = region_info

except KeyboardInterrupt:
    print("Processing interrupted. Saving current progress...")
finally:
    activity_consume_df.to_csv(output_file_path, index=False, encoding='utf-8-sig')
    print(f"Partial results saved to: {output_file_path}")

print(f"Final results saved to: {output_file_path}")
# Out:
# Resuming from saved file: tn_visit_area_info_방문지정보2nd.csv
# Initial data size: (100761, 32)
# Data size after removing rows with all 4 values missing: (100761, 32)
# Processing ROAD_NM_ADDR, X_COORD, Y_COORD...
# Attempting to geocode address: 서울 마포구 상암동 495-72
# Geocode success for address: 서울 마포구 상암동 495-72
# Attempting to geocode address: 인천 중구 북성동1가 98-580
# Geocode success for address: 인천 중구 북성동1가 98-580
# Attempting to geocode address: 서울 영등포구 여의도동 85
# Geocode success for address: 서울 영등포구 여의도동 85
# Attempting to geocode address: 서울 종로구 동숭동 50-111
# Geocode success for address: 서울 종로구 동숭동 50-111
# Cache hit for address: 서울 종로구 동숭동 50-111
# Attempting to geocode address: 경기 성남시 분당구 율동 318
# Geocode success for address: 경기 성남시 분당구 율동 318
# Cache hit for address: 경기 성남시 분당구 율동 318
# Attempting to geocode address: 경기 수원시 팔달구 인계동 1132-4
# Geocode success for address: 경기 수원시 팔달구 인계동 1132-4
# Attempting to geocode address: 경기 수원시 팔달구 신풍동 64-1
# Geocode success for address: 경기 수원시 팔달구 신풍동 64-1
# Attempting to geocode address: 경기 오산시 수청동 332-4
# Geocode success for address: 경기 오산시 수청동 332-4
# Attempting to geocode address: 인천 중구 운서동 2848-6
# Geocode success for address: 인천 중구 운서동 2848-6
# C:\Users\zx12c\AppData\Local\Temp\ipykernel_29616\437347009.py:137: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '126.472977579409' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   activity_consume_df.at[index, 'X_COORD'] = x_coord
# C:\Users\zx12c\AppData\Local\Temp\ipykernel_29616\437347009.py:138: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '37.4466183340394' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   activity_consume_df.at[index, 'Y_COORD'] = y_coord
# Attempting to geocode address: 경기 시흥시 조남동 190-1
# Geocode success for address: 경기 시흥시 조남동 190-1
# Attempting to geocode address: 서울 서초구 방배동 2529
# Geocode success for address: 서울 서초구 방배동 2529
# Attempting to geocode address: 경기 오산시 양산동 산 19-3
# Geocode success for address: 경기 오산시 양산동 산 19-3
# Attempting to geocode address: 경기 안양시 만안구 석수동 825-1
# Geocode success for address: 경기 안양시 만안구 석수동 825-1
# Attempting to geocode address: 서울 영등포구 영등포동 618-496
# Geocode success for address: 서울 영등포구 영등포동 618-496
# Attempting to geocode address: 서울 성동구 성수동1가 668-11
# Geocode success for address: 서울 성동구 성수동1가 668-11
# Attempting to geocode address: 서울 서초구 반포동
# Geocode success for address: 서울 서초구 반포동
# Attempting to geocode address: 경기 파주시 광탄면 기산리 481-1
# Geocode success for address: 경기 파주시 광탄면 기산리 481-1
# Attempting to geocode address: 경기 연천군 중면 횡산리 산 109
# Geocode success for address: 경기 연천군 중면 횡산리 산 109
# Attempting to geocode address: 경기 연천군 연천읍 부곡리 193
# Geocode success for address: 경기 연천군 연천읍 부곡리 193
# Attempting to geocode address: 인천 중구 운서동 2877-1
# Geocode success for address: 인천 중구 운서동 2877-1
# Attempting to geocode address: 서울 서초구 반포동 19-3
# Geocode success for address: 서울 서초구 반포동 19-3
# Cache hit for address: 서울 마포구 상암동 495-72
# Attempting to geocode address: 경기 포천시 영북면 산정리
# Geocode success for address: 경기 포천시 영북면 산정리
# Attempting to geocode address: 서울 종로구 숭인동 239-9
# Geocode success for address: 서울 종로구 숭인동 239-9
# Attempting to geocode address: 경기 포천시 영북면 대회산리 377
# Geocode success for address: 경기 포천시 영북면 대회산리 377
# Attempting to geocode address: 경기 포천시 영북면 자일리
# Geocode success for address: 경기 포천시 영북면 자일리
# Attempting to geocode address: 경기 포천시 영북면 대회산리 415-2
# Geocode success for address: 경기 포천시 영북면 대회산리 415-2
# Attempting to geocode address: 경기 포천시 영중면 성동리
# Geocode success for address: 경기 포천시 영중면 성동리
# Attempting to geocode address: 부산 서구 초장동 54-4
# Geocode success for address: 부산 서구 초장동 54-4
# Cache hit for address: 부산 서구 초장동 54-4
# Attempting to geocode address: 부산 해운대구 우동 1524
# Geocode success for address: 부산 해운대구 우동 1524
# Cache hit for address: 부산 해운대구 우동 1524
# Cache hit for address: 부산 해운대구 우동 1524
# Attempting to geocode address: 경남 고성군 고성읍 서외리 82-5
# Geocode success for address: 경남 고성군 고성읍 서외리 82-5
# Attempting to geocode address: 강원특별자치도 정선군 사북읍 사북리 424
# Geocode success for address: 강원특별자치도 정선군 사북읍 사북리 424
# Attempting to geocode address: 경북 경주시 황남동 290-1
# Geocode success for address: 경북 경주시 황남동 290-1
# Attempting to geocode address: 울산 중구 태화동 486-17
# Geocode success for address: 울산 중구 태화동 486-17
# Attempting to geocode address: 울산 남구 달동 1262-2
# Geocode success for address: 울산 남구 달동 1262-2
# Attempting to geocode address: 경북 경주시 노서동 74
# Geocode success for address: 경북 경주시 노서동 74
# Attempting to geocode address: 경남 통영시 서호동 163-101
# Geocode success for address: 경남 통영시 서호동 163-101
# Attempting to geocode address: 경북 포항시 북구 여천동 73-3
# Geocode success for address: 경북 포항시 북구 여천동 73-3
# Cache hit for address: 경북 포항시 북구 여천동 73-3
# Attempting to geocode address: 강원특별자치도 강릉시 성남동 50
# Geocode success for address: 강원특별자치도 강릉시 성남동 50
# Attempting to geocode address: 경북 경주시 황남동 315-6
# Geocode success for address: 경북 경주시 황남동 315-6
# Attempting to geocode address: 경북 경주시 황남동 359-2
# Geocode success for address: 경북 경주시 황남동 359-2
# Attempting to geocode address: 경북 경주시 인왕동 839-1
# Geocode success for address: 경북 경주시 인왕동 839-1
# Attempting to geocode address: 강원특별자치도 춘천시 중도동 460
# Geocode success for address: 강원특별자치도 춘천시 중도동 460
# Attempting to geocode address: 강원특별자치도 강릉시 강문동 304-4
# Geocode success for address: 강원특별자치도 강릉시 강문동 304-4
# Attempting to geocode address: 강원특별자치도 평창군 방림면 계촌리 1520-6
# Geocode success for address: 강원특별자치도 평창군 방림면 계촌리 1520-6
# Attempting to geocode address: 강원특별자치도 평창군 대화면 대화리 산 538
# Geocode success for address: 강원특별자치도 평창군 대화면 대화리 산 538
# Attempting to geocode address: 경북 경주시 구황동 786-1
# Geocode success for address: 경북 경주시 구황동 786-1
# Attempting to geocode address: 강원특별자치도 삼척시 갈천동 14
# Geocode success for address: 강원특별자치도 삼척시 갈천동 14
# Attempting to geocode address: 충북 옥천군 옥천읍 하계리 1-1
# Geocode success for address: 충북 옥천군 옥천읍 하계리 1-1
# Attempting to geocode address: 부산 영도구 청학동 442-22
# Geocode success for address: 부산 영도구 청학동 442-22
# Attempting to geocode address: 강원특별자치도 원주시 태장동 1286-1
# Geocode success for address: 강원특별자치도 원주시 태장동 1286-1
# Attempting to geocode address: 강원특별자치도 강릉시 견소동 268-28
# Geocode success for address: 강원특별자치도 강릉시 견소동 268-28
# Attempting to geocode address: 부산 해운대구 우동 721
# Geocode success for address: 부산 해운대구 우동 721
# Attempting to geocode address: 부산 해운대구 우동 1151-7
# Geocode success for address: 부산 해운대구 우동 1151-7
# Attempting to geocode address: 경북 경주시 인왕동 910-30
# Geocode success for address: 경북 경주시 인왕동 910-30
# Attempting to geocode address: 경남 김해시 대청동 302-8
# Geocode success for address: 경남 김해시 대청동 302-8
# Attempting to geocode address: 경남 김해시 대청동 299
# Geocode success for address: 경남 김해시 대청동 299
# Attempting to geocode address: 강원특별자치도 인제군 인제읍 원대리 산 75-22
# Geocode success for address: 강원특별자치도 인제군 인제읍 원대리 산 75-22
# Attempting to geocode address: 경북 경주시 교동 274
# Geocode success for address: 경북 경주시 교동 274
# Attempting to geocode address: 부산 영도구 영선동4가 1044-6
# Geocode success for address: 부산 영도구 영선동4가 1044-6
# Attempting to geocode address: 강원특별자치도 양양군 현남면 남애리
# Geocode success for address: 강원특별자치도 양양군 현남면 남애리
# Attempting to geocode address: 강원특별자치도 고성군 토성면 아야진리
# Geocode success for address: 강원특별자치도 고성군 토성면 아야진리
# Attempting to geocode address: 강원특별자치도 평창군 봉평면 창동리 280-6
# Geocode success for address: 강원특별자치도 평창군 봉평면 창동리 280-6
# Cache hit for address: 강원특별자치도 춘천시 중도동 460
# Attempting to geocode address: 대구 중구 대봉동 6-11
# Geocode success for address: 대구 중구 대봉동 6-11
# Attempting to geocode address: 경북 경주시 천군동 205-51
# Geocode success for address: 경북 경주시 천군동 205-51
# Attempting to geocode address: 부산 기장군 기장읍 죽성리
# Geocode success for address: 부산 기장군 기장읍 죽성리
# Attempting to geocode address: 경북 안동시 남부동
# Geocode success for address: 경북 안동시 남부동
# Attempting to geocode address: 경북 안동시 풍천면 하회리 1176-1
# Geocode success for address: 경북 안동시 풍천면 하회리 1176-1
# Attempting to geocode address: 강원특별자치도 속초시 청호동
# Geocode success for address: 강원특별자치도 속초시 청호동
# Attempting to geocode address: 강원특별자치도 강릉시 주문진읍 향호리 8-35
# Geocode success for address: 강원특별자치도 강릉시 주문진읍 향호리 8-35
# Attempting to geocode address: 강원특별자치도 강릉시 안현동 235-5
# Geocode success for address: 강원특별자치도 강릉시 안현동 235-5
# Attempting to geocode address: 강원특별자치도 강릉시 죽헌동
# Geocode success for address: 강원특별자치도 강릉시 죽헌동
# Attempting to geocode address: 강원특별자치도 강릉시 강문동 182-1
# Geocode success for address: 강원특별자치도 강릉시 강문동 182-1
# Attempting to geocode address: 강원특별자치도 양양군 강현면 정암리
# Geocode success for address: 강원특별자치도 양양군 강현면 정암리
# Attempting to geocode address: 경북 안동시 상아동 423
# Geocode success for address: 경북 안동시 상아동 423
# Cache hit for address: 경북 안동시 풍천면 하회리 1176-1
# Attempting to geocode address: 경북 경산시 남산면 반곡리
# Geocode success for address: 경북 경산시 남산면 반곡리
# Attempting to geocode address: 경북 포항시 남구 호미곶면 대보리
# Geocode success for address: 경북 포항시 남구 호미곶면 대보리
# Attempting to geocode address: 경북 포항시 남구 구룡포읍 구룡포리 971-1
# Geocode success for address: 경북 포항시 남구 구룡포읍 구룡포리 971-1
# Attempting to geocode address: 경북 포항시 북구 두호동 685-1
# Geocode success for address: 경북 포항시 북구 두호동 685-1
# Attempting to geocode address: 경북 포항시 북구 두호동 산 8
# Geocode success for address: 경북 포항시 북구 두호동 산 8
# Attempting to geocode address: 경북 포항시 북구 득량동 66-5
# Geocode success for address: 경북 포항시 북구 득량동 66-5
# Attempting to geocode address: 강원특별자치도 홍천군 홍천읍 신장대리 85
# Geocode success for address: 강원특별자치도 홍천군 홍천읍 신장대리 85
# Attempting to geocode address: 경북 구미시 원평동 429-24
# Geocode success for address: 경북 구미시 원평동 429-24
# Attempting to geocode address: 부산 해운대구 우동
# Geocode success for address: 부산 해운대구 우동
# Attempting to geocode address: 부산 해운대구 우동 708-3
# Geocode success for address: 부산 해운대구 우동 708-3
# Cache hit for address: 경북 경주시 인왕동 910-30
# Attempting to geocode address: 경북 문경시 마성면 신현리 산 35-6
# Geocode success for address: 경북 문경시 마성면 신현리 산 35-6
# Attempting to geocode address: 경북 예천군 호명읍 산합리 1411
# Geocode success for address: 경북 예천군 호명읍 산합리 1411
# Attempting to geocode address: 경남 사천시 용현면 금문리 212-3
# Geocode success for address: 경남 사천시 용현면 금문리 212-3
# Attempting to geocode address: 강원특별자치도 속초시 설악동 111-1
# Geocode success for address: 강원특별자치도 속초시 설악동 111-1
# Cache hit for address: 경북 경주시 인왕동 910-30
# Attempting to geocode address: 경북 경주시 성건동
# Geocode success for address: 경북 경주시 성건동
# Cache hit for address: 경북 경주시 교동 274
# Cache hit for address: 경북 경주시 인왕동 910-30
# Cache hit for address: 강원특별자치도 삼척시 갈천동 14
# Attempting to geocode address: 서울 용산구 동자동 43-205
# Geocode success for address: 서울 용산구 동자동 43-205
# Attempting to geocode address: 부산 해운대구 우동 1413
# Geocode success for address: 부산 해운대구 우동 1413
# Attempting to geocode address: 경북 경주시 노서동 133-21
# Geocode success for address: 경북 경주시 노서동 133-21
# Attempting to geocode address: 강원특별자치도 강릉시 교동 138-8
# Geocode success for address: 강원특별자치도 강릉시 교동 138-8
# Cache hit for address: 강원특별자치도 강릉시 교동 138-8
# Attempting to geocode address: 경북 경주시 노서동 219-1
# Geocode success for address: 경북 경주시 노서동 219-1
# Cache hit for address: 경북 경주시 노서동 219-1
# Attempting to geocode address: 울산 남구 삼산동 8-26
# Geocode success for address: 울산 남구 삼산동 8-26
# Cache hit for address: 울산 남구 삼산동 8-26
# Cache hit for address: 울산 남구 삼산동 8-26
# Cache hit for address: 울산 남구 삼산동 8-26
# Attempting to geocode address: 경북 경주시 사정동 1-42
# Geocode success for address: 경북 경주시 사정동 1-42
# Cache hit for address: 경북 경주시 사정동 1-42
# Attempting to geocode address: 경북 청도군 청도읍 고수리 857-7
# Geocode success for address: 경북 청도군 청도읍 고수리 857-7
# Cache hit for address: 경북 경주시 인왕동 910-30
# Attempting to geocode address: 부산 동구 초량동 1187-1
# Geocode success for address: 부산 동구 초량동 1187-1
# Attempting to geocode address: 강원특별자치도 양양군 현남면 인구리 634-7
# Geocode success for address: 강원특별자치도 양양군 현남면 인구리 634-7
# Attempting to geocode address: 부산 영도구 영선동4가 1045
# Geocode success for address: 부산 영도구 영선동4가 1045
# Cache hit for address: 부산 영도구 영선동4가 1045
# Cache hit for address: 경북 경주시 인왕동 910-30
# Attempting to geocode address: 경북 경주시 황남동 270-10
# Geocode success for address: 경북 경주시 황남동 270-10
# Attempting to geocode address: 강원특별자치도 강릉시 송정동 산 1-4
# Geocode success for address: 강원특별자치도 강릉시 송정동 산 1-4
# Cache hit for address: 강원특별자치도 강릉시 송정동 산 1-4
# Attempting to geocode address: 부산 해운대구 우동 552-21
# Geocode success for address: 부산 해운대구 우동 552-21
# Attempting to geocode address: 경북 경주시 인왕동 449-1
# Geocode success for address: 경북 경주시 인왕동 449-1
# Attempting to geocode address: 경북 경주시 황오동 347-1
# Geocode success for address: 경북 경주시 황오동 347-1
# Attempting to geocode address: 경북 경주시 배동 1003
# Geocode success for address: 경북 경주시 배동 1003
# Cache hit for address: 경북 경주시 배동 1003
# Attempting to geocode address: 경북 포항시 남구 송도동 222
# Geocode success for address: 경북 포항시 남구 송도동 222
# Attempting to geocode address: 경북 경주시 황남동 268-10
# Geocode success for address: 경북 경주시 황남동 268-10
# Cache hit for address: 경북 포항시 남구 송도동 222
# Attempting to geocode address: 경북 고령군 대가야읍 지산리 460
# Geocode success for address: 경북 고령군 대가야읍 지산리 460
# Cache hit for address: 경북 고령군 대가야읍 지산리 460
# Cache hit for address: 경북 포항시 북구 두호동 산 8
# Cache hit for address: 경북 경주시 인왕동 910-30
# Attempting to geocode address: 경북 경주시 노서동 215
# Geocode success for address: 경북 경주시 노서동 215
# Attempting to geocode address: 경북 경주시 신평동 150-8
# Geocode success for address: 경북 경주시 신평동 150-8
# Cache hit for address: 경북 경주시 신평동 150-8
# Attempting to geocode address: 경기 하남시 천현동 267
# Geocode success for address: 경기 하남시 천현동 267
# Attempting to geocode address: 경북 경주시 천군동 1584-21
# Geocode success for address: 경북 경주시 천군동 1584-21
# Attempting to geocode address: 울산 중구 태화동 107
# Geocode success for address: 울산 중구 태화동 107
# Attempting to geocode address: 울산 남구 신정동 1540-4
# Geocode success for address: 울산 남구 신정동 1540-4
# Attempting to geocode address: 강원특별자치도 강릉시 연곡면 영진리 357-155
# Geocode success for address: 강원특별자치도 강릉시 연곡면 영진리 357-155
# Attempting to geocode address: 대구 중구 남일동 90
# Geocode success for address: 대구 중구 남일동 90
# Attempting to geocode address: 경북 경주시 충효동 2936-4
# Geocode success for address: 경북 경주시 충효동 2936-4
# Cache hit for address: 경북 경주시 충효동 2936-4
# Cache hit for address: 경북 경주시 충효동 2936-4
# Attempting to geocode address: 경북 경주시 황남동 294
# Geocode success for address: 경북 경주시 황남동 294
# Attempting to geocode address: 강원특별자치도 춘천시 북산면 청평리 산 205-2
# Geocode success for address: 강원특별자치도 춘천시 북산면 청평리 산 205-2
# Attempting to geocode address: 경기 광명시 일직동 276-1
# Geocode success for address: 경기 광명시 일직동 276-1
# Cache hit for address: 경기 광명시 일직동 276-1
# Cache hit for address: 부산 해운대구 우동 552-21
# Attempting to geocode address: 충북 충주시 대소원면 만정리 282-1
# Geocode success for address: 충북 충주시 대소원면 만정리 282-1
# Attempting to geocode address: 경남 남해군 상주면 상주리 2065
# Geocode success for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Attempting to geocode address: 경남 남해군 미조면 송정리 1029-13
# Geocode success for address: 경남 남해군 미조면 송정리 1029-13
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Attempting to geocode address: 경남 남해군 남면 홍현리 898-5
# Geocode success for address: 경남 남해군 남면 홍현리 898-5
# Cache hit for address: 경남 남해군 미조면 송정리 1029-13
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Cache hit for address: 경남 남해군 상주면 상주리 2065
# Attempting to geocode address: 강원특별자치도 고성군 죽왕면 공현진리 143-38
# Geocode success for address: 강원특별자치도 고성군 죽왕면 공현진리 143-38
# Attempting to geocode address: 강원특별자치도 인제군 북면 용대리 산 12-21
# Geocode success for address: 강원특별자치도 인제군 북면 용대리 산 12-21
# Attempting to geocode address: 부산 해운대구 중동 1124-8
# Geocode success for address: 부산 해운대구 중동 1124-8
# Cache hit for address: 부산 해운대구 우동
# Attempting to geocode address: 부산 해운대구 우동 1521
# Geocode success for address: 부산 해운대구 우동 1521
# Cache hit for address: 경북 경주시 인왕동 910-30
# Cache hit for address: 경북 경주시 교동 274
# Cache hit for address: 부산 동구 초량동 1187-1
# Attempting to geocode address: 대구 동구 신암동 596-4
# Geocode success for address: 대구 동구 신암동 596-4
# Attempting to geocode address: 강원특별자치도 속초시 청호동 550-14
# Geocode success for address: 강원특별자치도 속초시 청호동 550-14
# Attempting to geocode address: 대구 중구 봉산동 35-62
# Geocode success for address: 대구 중구 봉산동 35-62
# Cache hit for address: 대구 중구 봉산동 35-62
# Cache hit for address: 경북 경주시 사정동 1-42
# Attempting to geocode address: 경북 경주시 황남동 221-11
# Geocode success for address: 경북 경주시 황남동 221-11
# Cache hit for address: 경북 경주시 사정동 1-42
# Cache hit for address: 경북 경주시 사정동 1-42
# Cache hit for address: 경북 경주시 사정동 1-42
# Cache hit for address: 경북 경주시 황남동 221-11
# Attempting to geocode address: 경남 거창군 위천면 강천리 790
# Geocode success for address: 경남 거창군 위천면 강천리 790
# Attempting to geocode address: 경남 거창군 위천면 황산리 575-4
# Geocode success for address: 경남 거창군 위천면 황산리 575-4
# Attempting to geocode address: 경기 수원시 팔달구 장안동 331
# Geocode success for address: 경기 수원시 팔달구 장안동 331
# Attempting to geocode address: 충남 아산시 온천동 240
# Geocode success for address: 충남 아산시 온천동 240
# Attempting to geocode address: 전북특별자치도 정읍시 금붕동 954
# Geocode success for address: 전북특별자치도 정읍시 금붕동 954
# Attempting to geocode address: 충남 공주시 우성면 신웅리 산 26-8
# Geocode success for address: 충남 공주시 우성면 신웅리 산 26-8
# Attempting to geocode address: 전북특별자치도 전주시 완산구 고사동
# Geocode success for address: 전북특별자치도 전주시 완산구 고사동
# Attempting to geocode address: 충북 충주시 목벌동 319-17
# Geocode success for address: 충북 충주시 목벌동 319-17
# Attempting to geocode address: 전남 순천시 덕월동 464-2
# Geocode success for address: 전남 순천시 덕월동 464-2
# Attempting to geocode address: 충북 옥천군 옥천읍 삼양리 125
# Geocode success for address: 충북 옥천군 옥천읍 삼양리 125
# Attempting to geocode address: 전남 여수시 신월동 1804
# Geocode success for address: 전남 여수시 신월동 1804
# Attempting to geocode address: 전남 여수시 돌산읍 평사리 산 1-1
# Geocode success for address: 전남 여수시 돌산읍 평사리 산 1-1
# Attempting to geocode address: 충남 태안군 소원면 의항리 1235
# Geocode success for address: 충남 태안군 소원면 의항리 1235
# Attempting to geocode address: 충북 단양군 단양읍 도전리 654
# Geocode success for address: 충북 단양군 단양읍 도전리 654
# Attempting to geocode address: 대전 유성구 방동
# Geocode success for address: 대전 유성구 방동
# Attempting to geocode address: 전남 여수시 종화동
# Geocode success for address: 전남 여수시 종화동
# Attempting to geocode address: 충북 단양군 매포읍 하괴리 산 20-35
# Geocode success for address: 충북 단양군 매포읍 하괴리 산 20-35
# Attempting to geocode address: 산200-1
# No results found for address: 산200-1
# Attempting to geocode address: 산200-1
# No results found for address: 산200-1
# Attempting to geocode address: 서홍빌라
# No results found for address: 서홍빌라
# Attempting to geocode address: 서홍빌라
# No results found for address: 서홍빌라
# Attempting to geocode address: 에이스타워
# No results found for address: 에이스타워
# Attempting to geocode address: 에이스타워
# No results found for address: 에이스타워
# Attempting to geocode address: 제주 서귀포시 성산읍 일출로222 6월10일날 오픈한 프릳츠
# No results found for address: 제주 서귀포시 성산읍 일출로222 6월10일날 오픈한 프릳츠
# Attempting to geocode address: 제주 서귀포시 성산읍 일출로222 6월10일날 오픈한 프릳츠
# No results found for address: 제주 서귀포시 성산읍 일출로222 6월10일날 오픈한 프릳츠
# Attempting to geocode address: 도동 1길 5-18 박가네 따개비 칼국수
# No results found for address: 도동 1길 5-18 박가네 따개비 칼국수
# Attempting to geocode address: 도동 1길 5-18 박가네 따개비 칼국수
# No results found for address: 도동 1길 5-18 박가네 따개비 칼국수
# Attempting to geocode address: 알출로 174 1층
# No results found for address: 알출로 174 1층
# Attempting to geocode address: 알출로 174 1층
# No results found for address: 알출로 174 1층
# Attempting to geocode address: 공항 내 제주리식탁
# No results found for address: 공항 내 제주리식탁
# Attempting to geocode address: 공항 내 제주리식탁
# No results found for address: 공항 내 제주리식탁
# Attempting to geocode address: 산양산삼해물라면
# No results found for address: 산양산삼해물라면
# Attempting to geocode address: 산양산삼해물라면
# No results found for address: 산양산삼해물라면
# Attempting to geocode address: 산28
# No results found for address: 산28
# Attempting to geocode address: 산28
# No results found for address: 산28
# Attempting to geocode address: 포은대로313번길 45117
# No results found for address: 포은대로313번길 45117
# Attempting to geocode address: 포은대로313번길 45117
# No results found for address: 포은대로313번길 45117
# Attempting to geocode address: 인천대학교
# No results found for address: 인천대학교
# Attempting to geocode address: 인천대학교
# No results found for address: 인천대학교
# Attempting to geocode address: 서울 강서구 하늘길 37(명동 가츠라)
# No results found for address: 서울 강서구 하늘길 37(명동 가츠라)
# Attempting to geocode address: 서울 강서구 하늘길 37(명동 가츠라)
# No results found for address: 서울 강서구 하늘길 37(명동 가츠라)
# Attempting to geocode address: 유수암평화로5길 15-8
# No results found for address: 유수암평화로5길 15-8
# Attempting to geocode address: 유수암평화로5길 15-8
# No results found for address: 유수암평화로5길 15-8
# Attempting to geocode address: 선흘리 근교 들판
# No results found for address: 선흘리 근교 들판
# Attempting to geocode address: 선흘리 근교 들판
# No results found for address: 선흘리 근교 들판
# Attempting to geocode address: 민속해앗로 581-1
# No results found for address: 민속해앗로 581-1
# Attempting to geocode address: 민속해앗로 581-1
# No results found for address: 민속해앗로 581-1
# Attempting to geocode address: 안덕 어딘가
# No results found for address: 안덕 어딘가
# Attempting to geocode address: 안덕 어딘가
# No results found for address: 안덕 어딘가
# Attempting to geocode address: 보원아파트
# No results found for address: 보원아파트
# Attempting to geocode address: 보원아파트
# No results found for address: 보원아파트
# Attempting to geocode address: 보원아파트
# No results found for address: 보원아파트
# Attempting to geocode address: 보원아파트
# No results found for address: 보원아파트
# Attempting to geocode address: 산30-8
# No results found for address: 산30-8
# Attempting to geocode address: 산30-8
# No results found for address: 산30-8
# Attempting to geocode address: 제주특별자치도 제주시 우도면 연평리 산 23
# Geocode success for address: 제주특별자치도 제주시 우도면 연평리 산 23
# Attempting to geocode address: 제주신화월드
# No results found for address: 제주신화월드
# Attempting to geocode address: 제주신화월드
# No results found for address: 제주신화월드
# Attempting to geocode address: 제주 중정로 73길 22
# No results found for address: 제주 중정로 73길 22
# Attempting to geocode address: 제주 중정로 73길 22
# No results found for address: 제주 중정로 73길 22
# Attempting to geocode address: 대박명가b
# No results found for address: 대박명가b
# Attempting to geocode address: 대박명가b
# No results found for address: 대박명가b
# Attempting to geocode address: 산 164-1
# No results found for address: 산 164-1
# Attempting to geocode address: 산 164-1
# No results found for address: 산 164-1
# Attempting to geocode address: 인터시티 365호텔
# No results found for address: 인터시티 365호텔
# Attempting to geocode address: 인터시티 365호텔
# No results found for address: 인터시티 365호텔
# Attempting to geocode address: 제주특별자치도 제주시 한경면 판포리
# Geocode success for address: 제주특별자치도 제주시 한경면 판포리
# Attempting to geocode address: 제주특별자치도 제주시 한경면 고산리 3760
# Geocode success for address: 제주특별자치도 제주시 한경면 고산리 3760
# Attempting to geocode address: 지인 집2
# No results found for address: 지인 집2
# Attempting to geocode address: 지인 집2
# No results found for address: 지인 집2
# Attempting to geocode address: Sk 주유소
# No results found for address: Sk 주유소
# Attempting to geocode address: Sk 주유소
# No results found for address: Sk 주유소
# Attempting to geocode address: flavour6 food court
# No results found for address: flavour6 food court
# Attempting to geocode address: flavour6 food court
# No results found for address: flavour6 food court
# Attempting to geocode address: 스타벅스 남원DT점
# No results found for address: 스타벅스 남원DT점
# Attempting to geocode address: 스타벅스 남원DT점
# No results found for address: 스타벅스 남원DT점
# Attempting to geocode address: 복현화성타운
# No results found for address: 복현화성타운
# Attempting to geocode address: 복현화성타운
# No results found for address: 복현화성타운
# Attempting to geocode address: 아트하우스 두드림
# No results found for address: 아트하우스 두드림
# Attempting to geocode address: 아트하우스 두드림
# No results found for address: 아트하우스 두드림
# Attempting to geocode address: 등용로96-7
# No results found for address: 등용로96-7
# Attempting to geocode address: 등용로96-7
# No results found for address: 등용로96-7
# Attempting to geocode address: 신화역사로304번길 38 B1-33 셀렉더테이블 오슬로
# No results found for address: 신화역사로304번길 38 B1-33 셀렉더테이블 오슬로
# Attempting to geocode address: 신화역사로304번길 38 B1-33 셀렉더테이블 오슬로
# No results found for address: 신화역사로304번길 38 B1-33 셀렉더테이블 오슬로
# Attempting to geocode address: 무릉리 바다
# No results found for address: 무릉리 바다
# Attempting to geocode address: 무릉리 바다
# No results found for address: 무릉리 바다
# Attempting to geocode address: 북서길 56-1
# No results found for address: 북서길 56-1
# Attempting to geocode address: 북서길 56-1
# No results found for address: 북서길 56-1
# Attempting to geocode address: 도리로 841층
# No results found for address: 도리로 841층
# Attempting to geocode address: 도리로 841층
# No results found for address: 도리로 841층
# Attempting to geocode address: 실수로 공항에서 시작 버튼
# No results found for address: 실수로 공항에서 시작 버튼
# Attempting to geocode address: 실수로 공항에서 시작 버튼
# No results found for address: 실수로 공항에서 시작 버튼
# Attempting to geocode address: 숙소.
# No results found for address: 숙소.
# Attempting to geocode address: 숙소.
# No results found for address: 숙소.
# Attempting to geocode address: 숙소
# No results found for address: 숙소
# Attempting to geocode address: 숙소
# No results found for address: 숙소
# Attempting to geocode address: 하도리 랜드마크
# No results found for address: 하도리 랜드마크
# Attempting to geocode address: 하도리 랜드마크
# No results found for address: 하도리 랜드마크
# Attempting to geocode address: 미쁜제과 앞 돌고래 스팟
# No results found for address: 미쁜제과 앞 돌고래 스팟
# Attempting to geocode address: 미쁜제과 앞 돌고래 스팟
# No results found for address: 미쁜제과 앞 돌고래 스팟
# Attempting to geocode address: 제즈 서귀포시 성산읍 성산중앙로 19번길 14 2층
# No results found for address: 제즈 서귀포시 성산읍 성산중앙로 19번길 14 2층
# Attempting to geocode address: 제즈 서귀포시 성산읍 성산중앙로 19번길 14 2층
# No results found for address: 제즈 서귀포시 성산읍 성산중앙로 19번길 14 2층
# Attempting to geocode address: 지인집
# No results found for address: 지인집
# Attempting to geocode address: 지인집
# No results found for address: 지인집
# Attempting to geocode address: 고내로길7 45-3
# No results found for address: 고내로길7 45-3
# Attempting to geocode address: 고내로길7 45-3
# No results found for address: 고내로길7 45-3
# Attempting to geocode address: 중문오션힐스 1층
# No results found for address: 중문오션힐스 1층
# Attempting to geocode address: 중문오션힐스 1층
# No results found for address: 중문오션힐스 1층
# Attempting to geocode address: 부산 강서구 공항진입로 108
# No results found for address: 부산 강서구 공항진입로 108
# Attempting to geocode address: 제주특별자치도 제주시 삼양이동 1960-4
# Geocode success for address: 제주특별자치도 제주시 삼양이동 1960-4
# Attempting to geocode address: 제주특별자치도 제주시 해안동
# Geocode success for address: 제주특별자치도 제주시 해안동
# Cache hit for address: 제주특별자치도 제주시 한경면 판포리
# Attempting to geocode address: 제주특별자치도 제주시 한경면 판포리 2881-3
# Geocode success for address: 제주특별자치도 제주시 한경면 판포리 2881-3
# Attempting to geocode address: 제주특별자치도 제주시 일도1동
# Geocode success for address: 제주특별자치도 제주시 일도1동
# Attempting to geocode address: 제주특별자치도 서귀포시 대정읍 하모리 822-7
# Geocode success for address: 제주특별자치도 서귀포시 대정읍 하모리 822-7
# Attempting to geocode address: 제주특별자치도 서귀포시 대정읍 하모리 646-21
# Geocode success for address: 제주특별자치도 서귀포시 대정읍 하모리 646-21
# Attempting to geocode address: 제주특별자치도 서귀포시 대정읍 가파리 276
# Geocode success for address: 제주특별자치도 서귀포시 대정읍 가파리 276
# Attempting to geocode address: 동탄대로9길 19  2630-103
# No results found for address: 동탄대로9길 19  2630-103
# Attempting to geocode address: 동탄대로9길 19  2630-103
# No results found for address: 동탄대로9길 19  2630-103
# Attempting to geocode address: 제주특별자치도 제주시 한경면 고산리
# Geocode success for address: 제주특별자치도 제주시 한경면 고산리
# Attempting to geocode address: 김포공항 국내선 Kal Lounge
# No results found for address: 김포공항 국내선 Kal Lounge
# Attempting to geocode address: 김포공항 국내선 Kal Lounge
# No results found for address: 김포공항 국내선 Kal Lounge
# Attempting to geocode address: 노형남1길
# No results found for address: 노형남1길
# Attempting to geocode address: 노형남1길
# No results found for address: 노형남1길
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 상가리 산 121
# Geocode success for address: 제주특별자치도 제주시 애월읍 상가리 산 121
# Attempting to geocode address: 제주특별자치도 제주시 이호일동 1665-13
# Geocode success for address: 제주특별자치도 제주시 이호일동 1665-13
# Attempting to geocode address: 제주특별자치도 제주시 일도일동 1104
# Geocode success for address: 제주특별자치도 제주시 일도일동 1104
# Cache hit for address: 제주특별자치도 제주시 한경면 판포리
# Attempting to geocode address: 제주특별자치도 제주시 구좌읍 행원리 575-6
# Geocode success for address: 제주특별자치도 제주시 구좌읍 행원리 575-6
# Attempting to geocode address: 제주특별자치도 제주시 구좌읍 김녕리 1200-5
# Geocode success for address: 제주특별자치도 제주시 구좌읍 김녕리 1200-5
# Attempting to geocode address: 제주특별자치도 제주시 도두일동 1734
# Geocode success for address: 제주특별자치도 제주시 도두일동 1734
# Attempting to geocode address: 해안도로
# No results found for address: 해안도로
# Attempting to geocode address: 해안도로
# No results found for address: 해안도로
# Attempting to geocode address: 세인공항리무진 내동상가지점
# No results found for address: 세인공항리무진 내동상가지점
# Attempting to geocode address: 세인공항리무진 내동상가지점
# No results found for address: 세인공항리무진 내동상가지점
# Attempting to geocode address: 부산 강서구 공항진입로 108
# No results found for address: 부산 강서구 공항진입로 108
# Cache hit for address: 제주특별자치도 제주시 이호일동 1665-13
# Cache hit for address: 제주특별자치도 제주시 구좌읍 행원리 575-6
# Attempting to geocode address: 함덕해수욕장 지역축제
# No results found for address: 함덕해수욕장 지역축제
# Attempting to geocode address: 함덕해수욕장 지역축제
# No results found for address: 함덕해수욕장 지역축제
# Attempting to geocode address: 김녕해수욕장 샤워실
# No results found for address: 김녕해수욕장 샤워실
# Attempting to geocode address: 김녕해수욕장 샤워실
# No results found for address: 김녕해수욕장 샤워실
# Attempting to geocode address: 성산일출봉
# No results found for address: 성산일출봉
# Attempting to geocode address: 성산일출봉
# No results found for address: 성산일출봉
# Attempting to geocode address: 현대아파트
# No results found for address: 현대아파트
# Attempting to geocode address: 현대아파트
# No results found for address: 현대아파트
# Attempting to geocode address: 홈플러스 강서점
# No results found for address: 홈플러스 강서점
# Attempting to geocode address: 홈플러스 강서점
# No results found for address: 홈플러스 강서점
# Attempting to geocode address: 홈플러스 강서점
# No results found for address: 홈플러스 강서점
# Attempting to geocode address: 홈플러스 강서점
# No results found for address: 홈플러스 강서점
# Attempting to geocode address: 새마을금고연수원 지하1층
# No results found for address: 새마을금고연수원 지하1층
# Attempting to geocode address: 새마을금고연수원 지하1층
# No results found for address: 새마을금고연수원 지하1층
# Attempting to geocode address: 홈플러스 강서점
# No results found for address: 홈플러스 강서점
# Attempting to geocode address: 홈플러스 강서점
# No results found for address: 홈플러스 강서점
# Attempting to geocode address: 제주특별자치도 서귀포시 색달동 산 1-2
# Geocode success for address: 제주특별자치도 서귀포시 색달동 산 1-2
# Attempting to geocode address: 제주특별자치도 서귀포시 강정동 5628
# Geocode success for address: 제주특별자치도 서귀포시 강정동 5628
# Attempting to geocode address: 제주특별자치도 제주시 우도면 연평리
# Geocode success for address: 제주특별자치도 제주시 우도면 연평리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Attempting to geocode address: 제주특별자치도 서귀포시 서홍동 2565
# Geocode success for address: 제주특별자치도 서귀포시 서홍동 2565
# Attempting to geocode address: 제주특별자치도 서귀포시 중문동 1920-1
# Geocode success for address: 제주특별자치도 서귀포시 중문동 1920-1
# Attempting to geocode address: 부산 강서구 공항진입로 108
# No results found for address: 부산 강서구 공항진입로 108
# Attempting to geocode address: 부산 강서구 공항진입로 108
# No results found for address: 부산 강서구 공항진입로 108
# Attempting to geocode address: 바이제주 건너편의 해안도로
# No results found for address: 바이제주 건너편의 해안도로
# Attempting to geocode address: 바이제주 건너편의 해안도로
# No results found for address: 바이제주 건너편의 해안도로
# Attempting to geocode address: 코오롱아파트
# No results found for address: 코오롱아파트
# Attempting to geocode address: 코오롱아파트
# No results found for address: 코오롱아파트
# Attempting to geocode address: 오저여
# No results found for address: 오저여
# Attempting to geocode address: 오저여
# No results found for address: 오저여
# Attempting to geocode address: 경남 통영시 욕지면 연화리
# Geocode success for address: 경남 통영시 욕지면 연화리
# Attempting to geocode address: 경남 통영시 욕지면 연화리 산 6-26
# Geocode success for address: 경남 통영시 욕지면 연화리 산 6-26
# Cache hit for address: 경남 통영시 욕지면 연화리
# Cache hit for address: 경남 통영시 욕지면 연화리
# Cache hit for address: 경남 통영시 욕지면 연화리
# Attempting to geocode address: 경남 통영시 중앙동 38-5
# Geocode success for address: 경남 통영시 중앙동 38-5
# Attempting to geocode address: 전남 신안군 자은면 한운리 산 231-2
# Geocode success for address: 전남 신안군 자은면 한운리 산 231-2
# Attempting to geocode address: 전남 신안군 안좌면 박지리
# Geocode success for address: 전남 신안군 안좌면 박지리
# Attempting to geocode address: 전남 신안군 도초면 발매리 1356
# Geocode success for address: 전남 신안군 도초면 발매리 1356
# Attempting to geocode address: 전남 신안군 흑산면 예리 166-9
# Geocode success for address: 전남 신안군 흑산면 예리 166-9
# Attempting to geocode address: 전남 신안군 흑산면 홍도리 94-8
# Geocode success for address: 전남 신안군 흑산면 홍도리 94-8
# Cache hit for address: 전남 신안군 흑산면 홍도리 94-8
# Attempting to geocode address: 전남 신안군 도초면 오류리 116-1
# Geocode success for address: 전남 신안군 도초면 오류리 116-1
# Attempting to geocode address: 전남 신안군 도초면 우이도리
# Geocode success for address: 전남 신안군 도초면 우이도리
# Cache hit for address: 전남 여수시 돌산읍 평사리 산 1-1
# Attempting to geocode address: 전남 여수시 돌산읍 우두리 799-76
# Geocode success for address: 전남 여수시 돌산읍 우두리 799-76
# Attempting to geocode address: 전남 여수시 중앙동 383
# Geocode success for address: 전남 여수시 중앙동 383
# Attempting to geocode address: 전남 여수시 고소동 268
# Geocode success for address: 전남 여수시 고소동 268
# Cache hit for address: 제주특별자치도 제주시 한경면 판포리
# Attempting to geocode address: 제주특별자치도 서귀포시 서홍동
# Geocode success for address: 제주특별자치도 서귀포시 서홍동
# Cache hit for address: 제주특별자치도 제주시 이호일동 1665-13
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 곽지리 1359
# Geocode success for address: 제주특별자치도 제주시 애월읍 곽지리 1359
# Attempting to geocode address: 제주특별자치도 제주시 조천읍 선흘리 산 102-1
# Geocode success for address: 제주특별자치도 제주시 조천읍 선흘리 산 102-1
# Attempting to geocode address: 제주특별자치도 서귀포시 성산읍 성산리 78
# Geocode success for address: 제주특별자치도 서귀포시 성산읍 성산리 78
# Attempting to geocode address: 제주특별자치도 서귀포시 색달동 3039
# Geocode success for address: 제주특별자치도 서귀포시 색달동 3039
# Cache hit for address: 제주특별자치도 서귀포시 서홍동 2565
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 곽지리 1565
# Geocode success for address: 제주특별자치도 제주시 애월읍 곽지리 1565
# Attempting to geocode address: 제주특별자치도 제주시 한림읍 금악리 산 1-1
# Geocode success for address: 제주특별자치도 제주시 한림읍 금악리 산 1-1
# Attempting to geocode address: 제주특별자치도 제주시 구좌읍 송당리 2173
# Geocode success for address: 제주특별자치도 제주시 구좌읍 송당리 2173
# Cache hit for address: 제주특별자치도 제주시 이호일동 1665-13
# Attempting to geocode address: 제주특별자치도 제주시 조천읍 교래리
# Geocode success for address: 제주특별자치도 제주시 조천읍 교래리
# Attempting to geocode address: 제주특별자치도 제주시 구좌읍 김녕리 6145
# Geocode success for address: 제주특별자치도 제주시 구좌읍 김녕리 6145
# Attempting to geocode address: 제주특별자치도 서귀포시 성산읍 성산리
# Geocode success for address: 제주특별자치도 서귀포시 성산읍 성산리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 성산리 78
# Attempting to geocode address: 제주특별자치도 제주시 구좌읍 월정리 33-3
# Geocode success for address: 제주특별자치도 제주시 구좌읍 월정리 33-3
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 성산리 78
# Attempting to geocode address: 제주특별자치도 제주시 일도일동 1296-5
# Geocode success for address: 제주특별자치도 제주시 일도일동 1296-5
# Cache hit for address: 제주특별자치도 제주시 애월읍 곽지리 1565
# Attempting to geocode address: 김령리 1296-1
# No results found for address: 김령리 1296-1
# Attempting to geocode address: 김령리 1296-1
# No results found for address: 김령리 1296-1
# Cache hit for address: 제주특별자치도 제주시 이호일동 1665-13
# Attempting to geocode address: 제주특별자치도 제주시 삼도이동 1158-1
# Geocode success for address: 제주특별자치도 제주시 삼도이동 1158-1
# Attempting to geocode address: 가는길에 우연히 발견  주소조회가 안됨
# No results found for address: 가는길에 우연히 발견  주소조회가 안됨
# Attempting to geocode address: 제주특별자치도 서귀포시 안덕면 사계리 2147-33
# Geocode success for address: 제주특별자치도 서귀포시 안덕면 사계리 2147-33
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 성산리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 구엄리
# Geocode success for address: 제주특별자치도 제주시 애월읍 구엄리
# Cache hit for address: 제주특별자치도 제주시 한림읍 금악리 산 1-1
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 상가리 536
# Geocode success for address: 제주특별자치도 제주시 애월읍 상가리 536
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 고내리 462
# Geocode success for address: 제주특별자치도 제주시 애월읍 고내리 462
# Attempting to geocode address: 서문시장
# No results found for address: 서문시장
# Attempting to geocode address: 신동아아파크(B)
# No results found for address: 신동아아파크(B)
# Attempting to geocode address: 신동아아파크(B)
# No results found for address: 신동아아파크(B)
# Attempting to geocode address: 제주특별자치도 서귀포시 표선면 표선리
# Geocode success for address: 제주특별자치도 서귀포시 표선면 표선리
# Cache hit for address: 제주특별자치도 서귀포시 서홍동 2565
# Cache hit for address: 제주특별자치도 제주시 삼양이동 1960-4
# Attempting to geocode address: 제주특별자치도 서귀포시 안덕면 사계리 산 16
# Geocode success for address: 제주특별자치도 서귀포시 안덕면 사계리 산 16
# Cache hit for address: 제주특별자치도 서귀포시 안덕면 사계리 산 16
# Attempting to geocode address: 제주특별자치도 서귀포시 서홍동 791
# Geocode success for address: 제주특별자치도 서귀포시 서홍동 791
# Cache hit for address: 제주특별자치도 제주시 이호일동 1665-13
# Attempting to geocode address: 화순로 191-1 비행기 ㅡ 아시아나 126 000원 택시 35 400원
# No results found for address: 화순로 191-1 비행기 ㅡ 아시아나 126 000원 택시 35 400원
# Attempting to geocode address: 화순로 191-1 비행기 ㅡ 아시아나 126 000원 택시 35 400원
# No results found for address: 화순로 191-1 비행기 ㅡ 아시아나 126 000원 택시 35 400원
# Attempting to geocode address: 제주특별자치도 제주시 구좌읍 행원리 1950-6
# Geocode success for address: 제주특별자치도 제주시 구좌읍 행원리 1950-6
# Attempting to geocode address: 신록남로 786
# No results found for address: 신록남로 786
# Attempting to geocode address: 신록남로 786
# No results found for address: 신록남로 786
# Attempting to geocode address: 해안도로
# No results found for address: 해안도로
# Attempting to geocode address: 해안도로
# No results found for address: 해안도로
# Attempting to geocode address: 파시문화거리
# No results found for address: 파시문화거리
# Attempting to geocode address: 파시문화거리
# No results found for address: 파시문화거리
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 하가리 1607-3
# Geocode success for address: 제주특별자치도 제주시 애월읍 하가리 1607-3
# Attempting to geocode address: 테라도스
# No results found for address: 테라도스
# Attempting to geocode address: 애월문개항아리
# No results found for address: 애월문개항아리
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 애월리 2462
# Geocode success for address: 제주특별자치도 제주시 애월읍 애월리 2462
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 애월리
# Geocode success for address: 제주특별자치도 제주시 애월읍 애월리
# Attempting to geocode address: 제주공항 국내선 4층
# No results found for address: 제주공항 국내선 4층
# Attempting to geocode address: 제주공항 국내선 4층
# No results found for address: 제주공항 국내선 4층
# Attempting to geocode address: 공항진입로 108
# No results found for address: 공항진입로 108
# Attempting to geocode address: 공항진입로 108
# No results found for address: 공항진입로 108
# Attempting to geocode address: 해안로715-1 1층
# No results found for address: 해안로715-1 1층
# Attempting to geocode address: 제주특별자치도 서귀포시 성산읍 고성리 297-1
# Geocode success for address: 제주특별자치도 서귀포시 성산읍 고성리 297-1
# Attempting to geocode address: 제주특별자치도 제주시 해안동 2137-1
# Geocode success for address: 제주특별자치도 제주시 해안동 2137-1
# Attempting to geocode address: 영일길 15 6-32
# No results found for address: 영일길 15 6-32
# Attempting to geocode address: 제주특별자치도 제주시 용담이동 883-4
# Geocode success for address: 제주특별자치도 제주시 용담이동 883-4
# Attempting to geocode address: 포시즌파크
# No results found for address: 포시즌파크
# Attempting to geocode address: 포시즌파크
# No results found for address: 포시즌파크
# Attempting to geocode address: 런던베이글 뒷편의 해변
# No results found for address: 런던베이글 뒷편의 해변
# Attempting to geocode address: 런던베이글 뒷편의 해변
# No results found for address: 런던베이글 뒷편의 해변
# Attempting to geocode address: 산15-1
# No results found for address: 산15-1
# Attempting to geocode address: 산15-1
# No results found for address: 산15-1
# Attempting to geocode address: 김해국제공항 국내선
# No results found for address: 김해국제공항 국내선
# Attempting to geocode address: 제주특별자치도 제주시 한림읍 금능리 2036-2
# Geocode success for address: 제주특별자치도 제주시 한림읍 금능리 2036-2
# Cache hit for address: 제주특별자치도 제주시 한림읍 금능리 2036-2
# Cache hit for address: 제주특별자치도 제주시 우도면 연평리
# Attempting to geocode address: 버스정류장
# No results found for address: 버스정류장
# Attempting to geocode address: 버스정류장
# No results found for address: 버스정류장
# Attempting to geocode address: 귤귤스토어
# No results found for address: 귤귤스토어
# Attempting to geocode address: 태우해안로172-33
# No results found for address: 태우해안로172-33
# Attempting to geocode address: 태우해안로172-33
# No results found for address: 태우해안로172-33
# Attempting to geocode address: 제주특별자치도 제주시 용담이동 2002
# Geocode success for address: 제주특별자치도 제주시 용담이동 2002
# Cache hit for address: 제주특별자치도 제주시 용담이동 2002
# Attempting to geocode address: 양천향교역 - 발산역 부근
# No results found for address: 양천향교역 - 발산역 부근
# Attempting to geocode address: 양천향교역 - 발산역 부근
# No results found for address: 양천향교역 - 발산역 부근
# Attempting to geocode address: 제주특별자치도 서귀포시 성산읍 고성리 46
# Geocode success for address: 제주특별자치도 서귀포시 성산읍 고성리 46
# Attempting to geocode address: 표선해수욕장주차장
# No results found for address: 표선해수욕장주차장
# Attempting to geocode address: 표선해수욕장주차장
# No results found for address: 표선해수욕장주차장
# Attempting to geocode address: 제주특별자치도 제주시 한림읍 금능리 1351-1
# Geocode success for address: 제주특별자치도 제주시 한림읍 금능리 1351-1
# Attempting to geocode address: 어음1리
# No results found for address: 어음1리
# Attempting to geocode address: 어음1리
# No results found for address: 어음1리
# Attempting to geocode address: 바다앞
# No results found for address: 바다앞
# Attempting to geocode address: 바다앞
# No results found for address: 바다앞
# Attempting to geocode address: 김해공항 2층
# No results found for address: 김해공항 2층
# Attempting to geocode address: 김해공항 2층
# No results found for address: 김해공항 2층
# Attempting to geocode address: 중문단지축구장 뒤편(바다쪽)
# No results found for address: 중문단지축구장 뒤편(바다쪽)
# Attempting to geocode address: 중문단지축구장 뒤편(바다쪽)
# No results found for address: 중문단지축구장 뒤편(바다쪽)
# Attempting to geocode address: 천제연폭포관리소
# No results found for address: 천제연폭포관리소
# Attempting to geocode address: 천제연폭포관리소
# No results found for address: 천제연폭포관리소
# Attempting to geocode address: 무료주차장
# No results found for address: 무료주차장
# Attempting to geocode address: 무료주차장
# No results found for address: 무료주차장
# Cache hit for address: 제주특별자치도 제주시 한림읍 금악리 산 1-1
# Cache hit for address: 제주특별자치도 제주시 구좌읍 월정리 33-3
# Attempting to geocode address: 제주특별자치도 서귀포시 안덕면 사계리
# Geocode success for address: 제주특별자치도 서귀포시 안덕면 사계리
# Attempting to geocode address: 전북특별자치도 군산시 삼학동 330-19
# Geocode success for address: 전북특별자치도 군산시 삼학동 330-19
# Attempting to geocode address: 양명초등학교
# No results found for address: 양명초등학교
# Attempting to geocode address: 양명초등학교
# No results found for address: 양명초등학교
# Attempting to geocode address: 금악리(1209)  금오름 입구앞
# No results found for address: 금악리(1209)  금오름 입구앞
# Attempting to geocode address: 금악리(1209)  금오름 입구앞
# No results found for address: 금악리(1209)  금오름 입구앞
# Attempting to geocode address: 제주특별자치도 제주시 우도면 연평리 1442
# Geocode success for address: 제주특별자치도 제주시 우도면 연평리 1442
# Attempting to geocode address: 제주특별자치도 제주시 한경면 신창리 1322-1
# Geocode success for address: 제주특별자치도 제주시 한경면 신창리 1322-1
# Attempting to geocode address: 제주 바다 목장
# No results found for address: 제주 바다 목장
# Attempting to geocode address: 민속촌 해안로 631-34
# No results found for address: 민속촌 해안로 631-34
# Attempting to geocode address: 미즈웰산부인과
# No results found for address: 미즈웰산부인과
# Attempting to geocode address: 미즈웰산부인과
# No results found for address: 미즈웰산부인과
# Attempting to geocode address: 대우프루지오아파트 모델하우스
# No results found for address: 대우프루지오아파트 모델하우스
# Attempting to geocode address: 대우프루지오아파트 모델하우스
# No results found for address: 대우프루지오아파트 모델하우스
# Attempting to geocode address: 제주특별자치도 서귀포시 색달동 2950-17
# Geocode success for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Attempting to geocode address: 예레동 3027-1
# No results found for address: 예레동 3027-1
# Cache hit for address: 제주특별자치도 서귀포시 색달동 2950-17
# Attempting to geocode address: 시어머님  시이모님  시할머님과 시할머니집에서  식사
# No results found for address: 시어머님  시이모님  시할머님과 시할머니집에서  식사
# Attempting to geocode address: 더샵인천스카이타워1단지
# No results found for address: 더샵인천스카이타워1단지
# Attempting to geocode address: 대한민국 제주특별자치도 서귀포시 법환동 163-9  63573
# No results found for address: 대한민국 제주특별자치도 서귀포시 법환동 163-9  63573
# Attempting to geocode address: 대한민국 제주특별자치도 서귀포시 법환동 163-9  63573
# No results found for address: 대한민국 제주특별자치도 서귀포시 법환동 163-9  63573
# Attempting to geocode address: 제주특별자치도 서귀포시 성산읍 고성리 298-5
# Geocode success for address: 제주특별자치도 서귀포시 성산읍 고성리 298-5
# Cache hit for address: 제주특별자치도 제주시 구좌읍 김녕리 1200-5
# Attempting to geocode address: 제주특별자치도 제주시 일도일동 1476-2
# Geocode success for address: 제주특별자치도 제주시 일도일동 1476-2
# Attempting to geocode address: 부산 강서구 공항진입로 108
# No results found for address: 부산 강서구 공항진입로 108
# Attempting to geocode address: 제주특별자치도 제주시 구좌읍 송당리 산 66-2
# Geocode success for address: 제주특별자치도 제주시 구좌읍 송당리 산 66-2
# Attempting to geocode address: 제주특별자치도 서귀포시 성산읍 수산리 1687-36
# No results found for address: 제주특별자치도 서귀포시 성산읍 수산리 1687-36
# Attempting to geocode address: 제주특별자치도 서귀포시 성산읍 수산리 1687-36
# No results found for address: 제주특별자치도 서귀포시 성산읍 수산리 1687-36
# Attempting to geocode address: 학하리슈빌포레
# No results found for address: 학하리슈빌포레
# Attempting to geocode address: 학하리슈빌포레
# No results found for address: 학하리슈빌포레
# Attempting to geocode address: 제주특별자치도 제주시 용담삼동 496
# Geocode success for address: 제주특별자치도 제주시 용담삼동 496
# Attempting to geocode address: 광주 광산구 신촌동 698-9
# Geocode success for address: 광주 광산구 신촌동 698-9
# Cache hit for address: 광주 광산구 신촌동 698-9
# Attempting to geocode address: 제주특별자치도 제주시 용담삼동 541-4
# Geocode success for address: 제주특별자치도 제주시 용담삼동 541-4
# Attempting to geocode address: 제주특별자치도 서귀포시 서귀동 162-1
# Geocode success for address: 제주특별자치도 서귀포시 서귀동 162-1
# Attempting to geocode address: 제주공항 2층
# No results found for address: 제주공항 2층
# Attempting to geocode address: 제주공항 2층
# No results found for address: 제주공항 2층
# Cache hit for address: 제주특별자치도 제주시 한림읍 금능리 1351-1
# Attempting to geocode address: 제주특별자치도 제주시 도두일동 2539-1
# Geocode success for address: 제주특별자치도 제주시 도두일동 2539-1
# Attempting to geocode address: 남지농장직판장에서 걸어 내려감
# No results found for address: 남지농장직판장에서 걸어 내려감
# Attempting to geocode address: 남지농장직판장에서 걸어 내려감
# No results found for address: 남지농장직판장에서 걸어 내려감
# Attempting to geocode address: 산이고운아파트
# No results found for address: 산이고운아파트
# Attempting to geocode address: 산이고운아파트
# No results found for address: 산이고운아파트
# Attempting to geocode address: 해안도립공원
# No results found for address: 해안도립공원
# Attempting to geocode address: 해안도립공원
# No results found for address: 해안도립공원
# Attempting to fill ROAD_NM_ADDR using coordinates: (126.842539, 33.331221)
# Attempting to geocode address: 가다가 잠깐 차 세우고 구경했다
# No results found for address: 가다가 잠깐 차 세우고 구경했다
# Attempting to geocode address: 가다가 잠깐 차 세우고 구경했다
# No results found for address: 가다가 잠깐 차 세우고 구경했다
# Attempting to geocode address: 함덕해수욕장
# No results found for address: 함덕해수욕장
# Attempting to geocode address: 함덕해수욕장
# No results found for address: 함덕해수욕장
# Attempting to geocode address: 함덕해수욕장
# No results found for address: 함덕해수욕장
# Attempting to geocode address: 함덕해수욕장
# No results found for address: 함덕해수욕장
# Attempting to geocode address: 선착장(함덕)
# No results found for address: 선착장(함덕)
# Attempting to geocode address: 선착장(함덕)
# No results found for address: 선착장(함덕)
# Attempting to geocode address: 방파제
# No results found for address: 방파제
# Attempting to geocode address: 방파제
# No results found for address: 방파제
# Attempting to geocode address: 함덕해수욕장
# No results found for address: 함덕해수욕장
# Attempting to geocode address: 함덕해수욕장
# No results found for address: 함덕해수욕장
# Attempting to geocode address: 제주특별자치도 제주시 연동 273
# Geocode success for address: 제주특별자치도 제주시 연동 273
# Attempting to geocode address: 제주도특뱔자치도 제주시 애월읍 구엄리 1229-2
# No results found for address: 제주도특뱔자치도 제주시 애월읍 구엄리 1229-2
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 신엄리 2719-3
# Geocode success for address: 제주특별자치도 제주시 애월읍 신엄리 2719-3
# Attempting to geocode address: 친지집
# No results found for address: 친지집
# Attempting to geocode address: 친지집
# No results found for address: 친지집
# Attempting to geocode address: 친지집
# No results found for address: 친지집
# Attempting to geocode address: 친지집
# No results found for address: 친지집
# Attempting to geocode address: 친지집
# No results found for address: 친지집
# Attempting to geocode address: 친지집
# No results found for address: 친지집
# Cache hit for address: 제주특별자치도 제주시 조천읍 교래리
# Attempting to geocode address: 제주특별자치도 제주시 구좌읍 송당리 2263
# Geocode success for address: 제주특별자치도 제주시 구좌읍 송당리 2263
# Attempting to geocode address: 제주특별자치도 제주시 애월읍 애월리 2008-6
# Geocode success for address: 제주특별자치도 제주시 애월읍 애월리 2008-6
# Attempting to geocode address: 섭지코지
# No results found for address: 섭지코지
# Cache hit for address: 제주특별자치도 제주시 애월읍 애월리 2008-6
# Attempting to geocode address: 제주특별자치도 제주시 용담삼동 969-2
# Geocode success for address: 제주특별자치도 제주시 용담삼동 969-2
# Attempting to geocode address: 해안도로
# No results found for address: 해안도로
# ...
# Region info updated for row 100601
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 대포동 산 39-5
# Cache hit for address: 제주특별자치도 서귀포시 대포동 산 39-5
# Region info found: {'address_name': '제주특별자치도 서귀포시 대포동 산 39-5', 'b_code': '5013011400', 'h_code': '5013061000', 'main_address_no': '39', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '중문동', 'region_3depth_name': '대포동', 'sub_address_no': '5', 'x': '126.45484372955', 'y': '33.2911076839433'}
# Region info updated for row 100605
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 용담삼동 2364-5
# Attempting to geocode address: 제주특별자치도 제주시 용담삼동 2364-5
# Geocode success for address: 제주특별자치도 제주시 용담삼동 2364-5
# Region info found: {'address_name': '제주특별자치도 제주시 용담삼동 2364-5', 'b_code': '5011011000', 'h_code': '5011058000', 'main_address_no': '2364', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '용담2동', 'region_3depth_name': '용담삼동', 'sub_address_no': '5', 'x': '126.49119241097', 'y': '33.5190702919117'}
# Region info updated for row 100609
# Attempting to retrieve region info for ROAD_NM_ADDR: 서울 강서구 공항동 1373
# Cache hit for address: 서울 강서구 공항동 1373
# Region info found: {'address_name': '서울 강서구 공항동 1373', 'b_code': '1150010800', 'h_code': '1150062000', 'main_address_no': '1373', 'mountain_yn': 'N', 'region_1depth_name': '서울', 'region_2depth_name': '강서구', 'region_3depth_h_name': '공항동', 'region_3depth_name': '공항동', 'sub_address_no': '', 'x': '126.808109224979', 'y': '37.5558909472488'}
# Region info updated for row 100616
# Attempting to retrieve region info for ROAD_NM_ADDR: 전남 신안군 임자면 진리 265-26
# Attempting to geocode address: 전남 신안군 임자면 진리 265-26
# Geocode success for address: 전남 신안군 임자면 진리 265-26
# Region info found: {'address_name': '전남 신안군 임자면 진리 265-26', 'b_code': '4691032027', 'h_code': '4691032000', 'main_address_no': '265', 'mountain_yn': 'N', 'region_1depth_name': '전남', 'region_2depth_name': '신안군', 'region_3depth_h_name': '임자면', 'region_3depth_name': '임자면 진리', 'sub_address_no': '26', 'x': '126.111610005198', 'y': '35.0846490386833'}
# Region info updated for row 100628
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 연동 270-5
# Cache hit for address: 제주특별자치도 제주시 연동 270-5
# Region info found: {'address_name': '제주특별자치도 제주시 연동 270-5', 'b_code': '5011013700', 'h_code': '5011065000', 'main_address_no': '270', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '연동', 'region_3depth_name': '연동', 'sub_address_no': '5', 'x': '126.491493896626', 'y': '33.4916708681401'}
# Region info updated for row 100641
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 구좌읍 종달리 산 28
# Cache hit for address: 제주특별자치도 제주시 구좌읍 종달리 산 28
# Region info found: {'address_name': '제주특별자치도 제주시 구좌읍 종달리 산 28', 'b_code': '5011025632', 'h_code': '5011025600', 'main_address_no': '28', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '구좌읍', 'region_3depth_name': '구좌읍 종달리', 'sub_address_no': '', 'x': '126.833554576698', 'y': '33.4612408545956'}
# Region info updated for row 100647
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 성산읍 성산리 78
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 성산리 78
# Region info found: {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 78', 'b_code': '5013025921', 'h_code': '5013025900', 'main_address_no': '78', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '성산읍', 'region_3depth_name': '성산읍 성산리', 'sub_address_no': '', 'x': '126.939440327497', 'y': '33.4591650941401'}
# Region info updated for row 100650
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 한림읍 월령리 359-3
# Cache hit for address: 제주특별자치도 제주시 한림읍 월령리 359-3
# Region info found: {'address_name': '제주특별자치도 제주시 한림읍 월령리 359-3', 'b_code': '5011025032', 'h_code': '5011025000', 'main_address_no': '359', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '한림읍', 'region_3depth_name': '한림읍 월령리', 'sub_address_no': '3', 'x': '126.215691134615', 'y': '33.37800098547'}
# Region info updated for row 100663
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 애월읍 곽지리 1565
# Cache hit for address: 제주특별자치도 제주시 애월읍 곽지리 1565
# Region info found: {'address_name': '제주특별자치도 제주시 애월읍 곽지리 1565', 'b_code': '5011025337', 'h_code': '5011025300', 'main_address_no': '1565', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '애월읍', 'region_3depth_name': '애월읍 곽지리', 'sub_address_no': '', 'x': '126.305537194637', 'y': '33.4507837937137'}
# Region info updated for row 100668
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 성산읍 성산리 78
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 성산리 78
# Region info found: {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 78', 'b_code': '5013025921', 'h_code': '5013025900', 'main_address_no': '78', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '성산읍', 'region_3depth_name': '성산읍 성산리', 'sub_address_no': '', 'x': '126.939440327497', 'y': '33.4591650941401'}
# Region info updated for row 100671
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 성산읍 고성리 224-33
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 고성리 224-33
# Region info found: {'address_name': '제주특별자치도 서귀포시 성산읍 고성리 224-33', 'b_code': '5013025924', 'h_code': '5013025900', 'main_address_no': '224', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '성산읍', 'region_3depth_name': '성산읍 고성리', 'sub_address_no': '33', 'x': '126.923894848289', 'y': '33.4523163676613'}
# Region info updated for row 100675
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 성산읍 오조리 313
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 오조리 313
# Region info found: {'address_name': '제주특별자치도 서귀포시 성산읍 오조리 313', 'b_code': '5013025922', 'h_code': '5013025900', 'main_address_no': '313', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '성산읍', 'region_3depth_name': '성산읍 오조리', 'sub_address_no': '', 'x': '126.92033622959', 'y': '33.4656915910835'}
# Region info updated for row 100681
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 애월읍 유수암리 산 138
# Cache hit for address: 제주특별자치도 제주시 애월읍 유수암리 산 138
# Region info found: {'address_name': '제주특별자치도 제주시 애월읍 유수암리 산 138', 'b_code': '5011025342', 'h_code': '5011025300', 'main_address_no': '138', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '애월읍', 'region_3depth_name': '애월읍 유수암리', 'sub_address_no': '', 'x': '126.415851594434', 'y': '33.3922398094166'}
# Region info updated for row 100687
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 대정읍 상모리 산 2
# Cache hit for address: 제주특별자치도 서귀포시 대정읍 상모리 산 2
# Region info found: {'address_name': '제주특별자치도 서귀포시 대정읍 상모리 산 2', 'b_code': '5013025021', 'h_code': '5013025000', 'main_address_no': '2', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '대정읍', 'region_3depth_name': '대정읍 상모리', 'sub_address_no': '', 'x': '126.290605775396', 'y': '33.1994361499843'}
# Region info updated for row 100691
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 안덕면 사계리 2032-51
# Cache hit for address: 제주특별자치도 서귀포시 안덕면 사계리 2032-51
# Region info found: {'address_name': '제주특별자치도 서귀포시 안덕면 사계리 2032-51', 'b_code': '5013031025', 'h_code': '5013031000', 'main_address_no': '2032', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '안덕면', 'region_3depth_name': '안덕면 사계리', 'sub_address_no': '51', 'x': '126.308498616916', 'y': '33.2286452763931'}
# Region info updated for row 100696
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 대정읍 상모리 산 2-13
# Cache hit for address: 제주특별자치도 서귀포시 대정읍 상모리 산 2-13
# Region info found: {'address_name': '제주특별자치도 서귀포시 대정읍 상모리 산 2-13', 'b_code': '5013025021', 'h_code': '5013025000', 'main_address_no': '2', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '대정읍', 'region_3depth_name': '대정읍 상모리', 'sub_address_no': '13', 'x': '126.293182216158', 'y': '33.1968454857901'}
# Region info updated for row 100698
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 남원읍 하례리 산 53-4
# Cache hit for address: 제주특별자치도 서귀포시 남원읍 하례리 산 53-4
# Region info found: {'address_name': '제주특별자치도 서귀포시 남원읍 하례리 산 53-4', 'b_code': '5013025328', 'h_code': '5013025300', 'main_address_no': '53', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '남원읍', 'region_3depth_name': '남원읍 하례리', 'sub_address_no': '4', 'x': '126.597749630071', 'y': '33.3169520924806'}
# Region info updated for row 100702
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 성산읍 수산리 3990
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 수산리 3990
# Region info found: {'address_name': '제주특별자치도 서귀포시 성산읍 수산리 3990', 'b_code': '5013025925', 'h_code': '5013025900', 'main_address_no': '3990', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '성산읍', 'region_3depth_name': '성산읍 수산리', 'sub_address_no': '', 'x': '126.843188469055', 'y': '33.4288682654423'}
# Region info updated for row 100704
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 대정읍 동일리 10
# Attempting to geocode address: 제주특별자치도 서귀포시 대정읍 동일리 10
# Geocode success for address: 제주특별자치도 서귀포시 대정읍 동일리 10
# Region info found: {'address_name': '제주특별자치도 서귀포시 대정읍 동일리 10', 'b_code': '5013025028', 'h_code': '5013025000', 'main_address_no': '10', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '대정읍', 'region_3depth_name': '대정읍 동일리', 'sub_address_no': '', 'x': '126.26102739626', 'y': '33.2542626733456'}
# Region info updated for row 100706
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 대정읍 상모리 산 2-13
# Cache hit for address: 제주특별자치도 서귀포시 대정읍 상모리 산 2-13
# Region info found: {'address_name': '제주특별자치도 서귀포시 대정읍 상모리 산 2-13', 'b_code': '5013025021', 'h_code': '5013025000', 'main_address_no': '2', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '대정읍', 'region_3depth_name': '대정읍 상모리', 'sub_address_no': '13', 'x': '126.293182216158', 'y': '33.1968454857901'}
# Region info updated for row 100712
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 하원동 산 1-1
# Cache hit for address: 제주특별자치도 서귀포시 하원동 산 1-1
# Region info found: {'address_name': '제주특별자치도 서귀포시 하원동 산 1-1', 'b_code': '5013011800', 'h_code': '5013061000', 'main_address_no': '1', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '중문동', 'region_3depth_name': '하원동', 'sub_address_no': '1', 'x': '126.476171521359', 'y': '33.333153339392'}
# Region info updated for row 100722
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 안덕면 사계리 112-3
# Cache hit for address: 제주특별자치도 서귀포시 안덕면 사계리 112-3
# Region info found: {'address_name': '제주특별자치도 서귀포시 안덕면 사계리 112-3', 'b_code': '5013031025', 'h_code': '5013031000', 'main_address_no': '112', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '안덕면', 'region_3depth_name': '안덕면 사계리', 'sub_address_no': '3', 'x': '126.314630553022', 'y': '33.2334821266939'}
# Region info updated for row 100729
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 안덕면 사계리 2032-51
# Cache hit for address: 제주특별자치도 서귀포시 안덕면 사계리 2032-51
# Region info found: {'address_name': '제주특별자치도 서귀포시 안덕면 사계리 2032-51', 'b_code': '5013031025', 'h_code': '5013031000', 'main_address_no': '2032', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '안덕면', 'region_3depth_name': '안덕면 사계리', 'sub_address_no': '51', 'x': '126.308498616916', 'y': '33.2286452763931'}
# Region info updated for row 100733
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 삼양이동 1960-4
# Cache hit for address: 제주특별자치도 제주시 삼양이동 1960-4
# Region info found: {'address_name': '제주특별자치도 제주시 삼양이동 1960-4', 'b_code': '5011011400', 'h_code': '5011061000', 'main_address_no': '1960', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '삼양동', 'region_3depth_name': '삼양이동', 'sub_address_no': '4', 'x': '126.585533890607', 'y': '33.5256830791377'}
# Region info updated for row 100739
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 성산읍 성산리 78
# Cache hit for address: 제주특별자치도 서귀포시 성산읍 성산리 78
# Region info found: {'address_name': '제주특별자치도 서귀포시 성산읍 성산리 78', 'b_code': '5013025921', 'h_code': '5013025900', 'main_address_no': '78', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '성산읍', 'region_3depth_name': '성산읍 성산리', 'sub_address_no': '', 'x': '126.939440327497', 'y': '33.4591650941401'}
# Region info updated for row 100741
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 해안동 2137-1
# Cache hit for address: 제주특별자치도 제주시 해안동 2137-1
# Region info found: {'address_name': '제주특별자치도 제주시 해안동 2137-1', 'b_code': '5011013900', 'h_code': '5011066000', 'main_address_no': '2137', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '노형동', 'region_3depth_name': '해안동', 'sub_address_no': '1', 'x': '126.455271713634', 'y': '33.4647769927847'}
# Region info updated for row 100747
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 서홍동 2565
# Cache hit for address: 제주특별자치도 서귀포시 서홍동 2565
# Region info found: {'address_name': '제주특별자치도 서귀포시 서홍동 2565', 'b_code': '5013010600', 'h_code': '5013058000', 'main_address_no': '2565', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '서홍동', 'region_3depth_name': '서홍동', 'sub_address_no': '', 'x': '126.554766074558', 'y': '33.2664146375473'}
# Region info updated for row 100752
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 하효동 990-1
# Cache hit for address: 제주특별자치도 서귀포시 하효동 990-1
# Region info found: {'address_name': '제주특별자치도 서귀포시 하효동 990-1', 'b_code': '5013010800', 'h_code': '5013055000', 'main_address_no': '990', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '효돈동', 'region_3depth_name': '하효동', 'sub_address_no': '1', 'x': '126.622297201204', 'y': '33.2540927304372'}
# Region info updated for row 100753
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 서귀포시 하효동 990-1
# Cache hit for address: 제주특별자치도 서귀포시 하효동 990-1
# Region info found: {'address_name': '제주특별자치도 서귀포시 하효동 990-1', 'b_code': '5013010800', 'h_code': '5013055000', 'main_address_no': '990', 'mountain_yn': 'N', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '서귀포시', 'region_3depth_h_name': '효돈동', 'region_3depth_name': '하효동', 'sub_address_no': '1', 'x': '126.622297201204', 'y': '33.2540927304372'}
# Region info updated for row 100754
# Attempting to retrieve region info for ROAD_NM_ADDR: 제주특별자치도 제주시 한림읍 금악리 산 1-1
# Cache hit for address: 제주특별자치도 제주시 한림읍 금악리 산 1-1
# Region info found: {'address_name': '제주특별자치도 제주시 한림읍 금악리 산 1-1', 'b_code': '5011025025', 'h_code': '5011025000', 'main_address_no': '1', 'mountain_yn': 'Y', 'region_1depth_name': '제주특별자치도', 'region_2depth_name': '제주시', 'region_3depth_h_name': '한림읍', 'region_3depth_name': '한림읍 금악리', 'sub_address_no': '1', 'x': '126.305586388283', 'y': '33.3556958434344'}
# Region info updated for row 100759
# Partial results saved to: tn_visit_area_info_방문지정보2nd.csv
# Final results saved to: tn_visit_area_info_방문지정보2nd.csv
